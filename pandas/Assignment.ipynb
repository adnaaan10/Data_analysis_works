# %%
import pandas as pd

# %% [markdown]
# # -Create a data frame which contains name and age of workshop participants(random age)-both dictionary and list

# %%
dict1={"Name":["adnan","messi","ronaldo"],"age":[21,35,36]}
dict1
# Out:
# {'Name': ['adnan', 'messi', 'ronaldo'], 'age': [21, 35, 36]}

# %%
pd.DataFrame(dict1)
# Out:
#       Name  age
# 0    adnan   21
# 1    messi   35
# 2  ronaldo   36

# %%
list1=["adnan","messi","ronaldo"]
list2=[21,35,36]
pd.DataFrame(zip(list1,list2),columns=["Name","age"])
# Out:
#       Name  age
# 0    adnan   21
# 1    messi   35
# 2  ronaldo   36

# %% [markdown]
# # -Read 5 different data sets and perform basics tasks

# %% [markdown]
# ## 1-laptops

# %%
kc=pd.read_csv("laptops.csv")
kc
# Out:
#      index   brand                                              Model  Price  \
# 0        1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1        2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2        3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3        4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4        5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
# ..     ...     ...                                                ...    ...
# 986    998    asus  Asus Vivobook Pro 15 M6500QC-HN542WS Laptop (R...  65990
# 987    999     msi  MSI Thin GF63 12VE-070IN Gaming Laptop (12th G...  91990
# 988   1000    asus  Asus Vivobook Go 15 2023 E1504FA-NJ522WS Lapto...  44990
# 989   1001    asus  Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop (...  67990
# 990   1002      hp  HP Chromebook 15a-na0008TU Laptop (Intel Celer...  20990
#
# ...

# %%
kc.size
# Out:
# 21802

# %%
kc.shape
# Out:
# (991, 22)

# %%
kc.columns
# Out:
# Index(['index', 'brand', 'Model', 'Price', 'Rating', 'processor_brand',
#        'processor_tier', 'num_cores', 'num_threads', 'ram_memory',
#        'primary_storage_type', 'primary_storage_capacity',
#        'secondary_storage_type', 'secondary_storage_capacity', 'gpu_brand',
#        'gpu_type', 'is_touch_screen', 'display_size', 'resolution_width',
#        'resolution_height', 'OS', 'year_of_warranty'],
#       dtype='object')

# %%
kc.head()
# Out:
#    index   brand                                              Model  Price  \
# 0      1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1      2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2      3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3      4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4      5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
#
#    Rating processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# 0      63           intel        core i3          2            4           8
# 1      67           intel        core i7          4            8          16
# 2      73             amd        ryzen 5          6           12           8
# 3      62           intel        core i5         12           16           8
# 4      62             amd        ryzen 3          4            8           8
#
# ...

# %%
kc.tail
# Out:
# <bound method NDFrame.tail of      index   brand                                              Model  Price  \
# 0        1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1        2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2        3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3        4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4        5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
# ..     ...     ...                                                ...    ...
# 986    998    asus  Asus Vivobook Pro 15 M6500QC-HN542WS Laptop (R...  65990
# 987    999     msi  MSI Thin GF63 12VE-070IN Gaming Laptop (12th G...  91990
# 988   1000    asus  Asus Vivobook Go 15 2023 E1504FA-NJ522WS Lapto...  44990
# 989   1001    asus  Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop (...  67990
# 990   1002      hp  HP Chromebook 15a-na0008TU Laptop (Intel Celer...  20990
#
# ...

# %% [markdown]
# ## 2-styles

# %%
a=pd.read_csv("styles.csv")
a
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44436  17036    Men       Footwear       Shoes           Casual Shoes
# 44437   6461    Men       Footwear  Flip Flops             Flip Flops
# 44438  18842    Men        Apparel     Topwear                Tshirts
# 44439  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44440  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
a.shape
# Out:
# (44441, 10)

# %%
a.size
# Out:
# 444410

# %%
a.columns
# Out:
# Index(['id', 'gender', 'masterCategory', 'subCategory', 'articleType',
#        'baseColour', 'season', 'year', 'usage', 'productDisplayName'],
#       dtype='object')

# %%
a.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
a.tail()
# Out:
#           id gender masterCategory subCategory            articleType  \
# 44436  17036    Men       Footwear       Shoes           Casual Shoes
# 44437   6461    Men       Footwear  Flip Flops             Flip Flops
# 44438  18842    Men        Apparel     Topwear                Tshirts
# 44439  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44440  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 44436      White  Summer  2013.0  Casual
# 44437        Red  Summer  2011.0  Casual
# 44438       Blue    Fall  2011.0  Casual
# 44439       Blue  Spring  2017.0  Casual
# 44440       Pink  Winter  2016.0  Casual
#
#                                     productDisplayName
# 44436                        Gas Men Caddy Casual Shoe
# 44437               Lotto Men's Soccer Track Flip Flop
# 44438             Puma Men Graphic Stellar Blue Tshirt
# 44439                   Rasasi Women Blue Lady Perfume
# ...

# %% [markdown]
# ## 3-worldcup matches

# %%
b=pd.read_csv("Fifa_world_cup_matches.csv")
b
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %%
b.shape
# Out:
# (64, 88)

# %%
b.size
# Out:
# 5632

# %%
b.columns
# Out:
# Index(['team1', 'team2', 'possession team1', 'possession team2',
#        'possession in contest', 'number of goals team1',
#        'number of goals team2', 'date', 'hour', 'category',
#        'total attempts team1', 'total attempts team2', 'conceded team1',
#        'conceded team2', 'goal inside the penalty area team1',
#        'goal inside the penalty area team2',
#        'goal outside the penalty area team1',
#        'goal outside the penalty area team2', 'assists team1', 'assists team2',
#        'on target attempts team1', 'on target attempts team2',
#        'off target attempts team1', 'off target attempts team2',
#        'attempts inside the penalty area team1',
#        'attempts inside the penalty area  team2',
#        'attempts outside the penalty area  team1',
#        'attempts outside the penalty area  team2', 'left channel team1',
#        'left channel team2', 'left inside channel team1',
#        'left inside channel team2', 'central channel team1',
# ...

# %%
b.head()
# Out:
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   possession in contest  number of goals team1  number of goals team2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
#           date     hour category  ...  penalties scored team1  \
# 0  20 NOV 2022  17 : 00  Group A  ...                       0
# ...

# %%
b.tail()
# Out:
#         team1    team2 possession team1 possession team2  \
# 59    ENGLAND   FRANCE              54%              36%
# 60  ARGENTINA  CROATIA              34%              54%
# 61     FRANCE  MOROCCO              34%              55%
# 62    CROATIA  MOROCCO              45%              45%
# 63  ARGENTINA   FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 59                   10%                      1                      2
# 60                   12%                      3                      0
# 61                   11%                      2                      0
# 62                   10%                      2                      1
# 63                   14%                      3                      3
#
#            date     hour                  category  ...  \
# 59  10 DEC 2022  20 : 00             Quarter-final  ...
# 60  13 DEC 2022  20 : 00                Semi-final  ...
# ...

# %% [markdown]
# ## 4-Temporary teachers

# %%
e=pd.read_csv("temporary_teachers.csv")
e
# Out:
#   Sl. No.                           Category  \
# 0       1                            General
# 1       2              Scheduled Castes (SC)
# 2       3              Scheduled Tribes (ST)
# 3       4       Other Backward Classes (OBC)
# 4       5  Economically Weaker Section (EWS)
# 5   Total                              Total
#
#    Number of Teachers Temporary Basis (including Contractual, ad-hoc etc.)
# 0                                               1783
# 1                                                165
# 2                                                192
# 3                                                337
# 4                                                 77
# 5                                               2554

# %%
e.size
# Out:
# 18

# %%
e.shape
# Out:
# (6, 3)

# %%
e.columns
# Out:
# Index(['Sl. No.', 'Category',
#        'Number of Teachers Temporary Basis (including Contractual, ad-hoc etc.)'],
#       dtype='object')

# %%
e.head()
# Out:
#   Sl. No.                           Category  \
# 0       1                            General
# 1       2              Scheduled Castes (SC)
# 2       3              Scheduled Tribes (ST)
# 3       4       Other Backward Classes (OBC)
# 4       5  Economically Weaker Section (EWS)
#
#    Number of Teachers Temporary Basis (including Contractual, ad-hoc etc.)
# 0                                               1783
# 1                                                165
# 2                                                192
# 3                                                337
# 4                                                 77

# %%
e.tail()
# Out:
#   Sl. No.                           Category  \
# 1       2              Scheduled Castes (SC)
# 2       3              Scheduled Tribes (ST)
# 3       4       Other Backward Classes (OBC)
# 4       5  Economically Weaker Section (EWS)
# 5   Total                              Total
#
#    Number of Teachers Temporary Basis (including Contractual, ad-hoc etc.)
# 1                                                165
# 2                                                192
# 3                                                337
# 4                                                 77
# 5                                               2554

# %% [markdown]
# ## 5-Tobacco survey

# %%
f=pd.read_csv("Youth_Tobacco_Survey__YTS__Data.csv")
f
# Out:
#        YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0      2004           OH           Ohio  Tobacco Use – Survey Data
# 1      2008           AL        Alabama  Tobacco Use – Survey Data
# 2      2015           WV  West Virginia  Tobacco Use – Survey Data
# 3      2005           IL       Illinois  Tobacco Use – Survey Data
# 4      2005           CT    Connecticut  Tobacco Use – Survey Data
# ...     ...          ...            ...                        ...
# 10595  2002           KS         Kansas  Tobacco Use – Survey Data
# 10596  2015           IL       Illinois  Tobacco Use – Survey Data
# 10597  2010           WI      Wisconsin  Tobacco Use – Survey Data
# 10598  2009           LA      Louisiana  Tobacco Use – Survey Data
# 10599  2010           DE       Delaware  Tobacco Use – Survey Data
#
#                            TopicDesc  \
# 0              Cigarette Use (Youth)
# 1              Cigarette Use (Youth)
# 2      Smokeless Tobacco Use (Youth)
# ...

# %%
f.size
# Out:
# 328600

# %%
f.shape
# Out:
# (10600, 31)

# %%
f.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'TopicType', 'TopicDesc',
#        'MeasureDesc', 'DataSource', 'Response', 'Data_Value_Unit',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Data_Value_Std_Err', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size', 'Gender', 'Race', 'Age',
#        'Education', 'GeoLocation', 'TopicTypeId', 'TopicId', 'MeasureId',
#        'StratificationID1', 'StratificationID2', 'StratificationID3',
#        'StratificationID4', 'SubMeasureID', 'DisplayOrder'],
#       dtype='object')

# %%
f.head()
# Out:
#    YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0  2004           OH           Ohio  Tobacco Use – Survey Data
# 1  2008           AL        Alabama  Tobacco Use – Survey Data
# 2  2015           WV  West Virginia  Tobacco Use – Survey Data
# 3  2005           IL       Illinois  Tobacco Use – Survey Data
# 4  2005           CT    Connecticut  Tobacco Use – Survey Data
#
#                        TopicDesc     MeasureDesc DataSource  Response  \
# 0          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 1          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 2  Smokeless Tobacco Use (Youth)     User Status        YTS  Frequent
# 3          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 4  Smokeless Tobacco Use (Youth)     User Status        YTS      Ever
#
#   Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0               %      Percentage  ...  (40.060210141, -82.404260056)
# ...

# %%
f.tail()
# Out:
#        YEAR LocationAbbr LocationDesc                  TopicType  \
# 10595  2002           KS       Kansas  Tobacco Use – Survey Data
# 10596  2015           IL     Illinois  Tobacco Use – Survey Data
# 10597  2010           WI    Wisconsin  Tobacco Use – Survey Data
# 10598  2009           LA    Louisiana  Tobacco Use – Survey Data
# 10599  2010           DE     Delaware  Tobacco Use – Survey Data
#
#                            TopicDesc  \
# 10595  Smokeless Tobacco Use (Youth)
# 10596          Cigarette Use (Youth)
# 10597              Cessation (Youth)
# 10598          Cigarette Use (Youth)
# 10599          Cigarette Use (Youth)
#
#                                              MeasureDesc DataSource  Response  \
# 10595                                        User Status        YTS  Frequent
# 10596                                     Smoking Status        YTS  Frequent
# 10597  Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# ...

# %% [markdown]
# # -Write a csv from tsv and excel

# %% [markdown]
# ## 1-tsv

# %%
nm=pandas.read_table("pandas_docs/test.tsv")
nm
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
nm.to_csv("test.csv")

# %%
pd.read_csv("test.csv")
# Out:
#   Unnamed: 0 Unnamed: 1     test     test   test.1   test.2  test.3
# 0     Magnus     Magnus   Magnus   Magnus   Magnus   Magnus     NaN
# 1    Carlsen    Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %% [markdown]
# ## 2-excel

# %%
mn=pandas.read_excel("pandas_docs/demo1.xlsx")
mn
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
mn.to_csv("demo1.csv")

# %%
pd.read_csv("demo1.csv")
# Out:
#    Unnamed: 0.1  Unnamed: 0  a   b   c   d message
# 0             0           0  1   2   3   4   hello
# 1             1           1  5   6   7   8   world
# 2             2           2  9  10  11  12     foo

# %% [markdown]
# # -read one data set from each resources of dataset we discussed

# %% [markdown]
# ## 1-kaggle

# %% [markdown]
# **Fashion Dataset**

# %%
pd.read_csv("styles.csv")
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44436  17036    Men       Footwear       Shoes           Casual Shoes
# 44437   6461    Men       Footwear  Flip Flops             Flip Flops
# 44438  18842    Men        Apparel     Topwear                Tshirts
# 44439  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44440  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %% [markdown]
# ## 2-Github

# %% [markdown]
# **Students Performance in Education**

# %%
pd.read_csv("https://raw.githubusercontent.com/rashida048/Datasets/master/StudentsPerformance.csv")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## 3-Data.gov.in

# %% [markdown]
# **Category-wise Number of Teachers Working on Temporary Basis in 45 Central Universities as on 01-04-2023**

# %%
pd.read_csv("temporary_teachers.csv")
# Out:
#   Sl. No.                           Category  \
# 0       1                            General
# 1       2              Scheduled Castes (SC)
# 2       3              Scheduled Tribes (ST)
# 3       4       Other Backward Classes (OBC)
# 4       5  Economically Weaker Section (EWS)
# 5   Total                              Total
#
#    Number of Teachers Temporary Basis (including Contractual, ad-hoc etc.)
# 0                                               1783
# 1                                                165
# 2                                                192
# 3                                                337
# 4                                                 77
# 5                                               2554
