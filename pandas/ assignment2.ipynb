# %%
import pandas as pd

# %%
df=pd.read_csv("pandas_docs/survey_results_public.csv")
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
ef=pd.read_csv("pandas_docs/survey_results_schema.csv")
ef
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %% [markdown]
# # retrieve first 5 rows with all columns|

# %%
df.iloc[[0,1,2,3,4,5],:]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# ...

# %% [markdown]
# # retrieve respondents 450,900,1350 with only their country,Hobbyist,YearsCode,Age1stCode|

# %%
df.columns.get_loc("Country")
# Out:
# 6

# %%
df.columns.get_loc("Hobbyist")
# Out:
# 2

# %%
df.columns.get_loc("YearsCode")
# Out:
# 13

# %%
df.columns.get_loc("Age1stCode")
# Out:
# 14

# %%
df.iloc[[450,900,1350],[6,2,13,14]]
# Out:
#             Country Hobbyist YearsCode Age1stCode
# 450   United States      Yes         7         28
# 900            Iran      Yes         6         16
# 1350         Mexico      Yes        10          9

# %% [markdown]
# # retrieve respondent 500 and his age

# %%
df.columns.get_loc("Age")
# Out:
# 77

# %%
df.iloc[500,77]
# Out:
# 21.0

# %% [markdown]
# # 1000t row > Country

# %%
df.loc[1000,"Country"]
# Out:
# 'United Kingdom'

# %% [markdown]
# # 30th row > Hobbyist

# %%
df.loc[30,"Hobbyist"]
# Out:
# 'No'

# %% [markdown]
# # 300th row >devtype

# %%
df.loc[300,"DevType"]
# Out:
# 'Developer, back-end;Developer, desktop or enterprise applications;Developer, game or graphics'

# %% [markdown]
# # acess 50-150

# %%
df.iloc[50:150]
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 50           51             I am a student who is learning to code      Yes
# 51           52                     I am a developer by profession      Yes
# 52           53  I am not primarily a developer, but I write co...      Yes
# 53           54                     I am a developer by profession      Yes
# 54           55             I am a student who is learning to code      Yes
# ..          ...                                                ...      ...
# 145         147                     I am a developer by profession       No
# 146         148                     I am a developer by profession      Yes
# 147         149                     I am a developer by profession      Yes
# 148         150                     I am a developer by profession      Yes
# 149         151                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# # acess without starting point

# %%
df.iloc[:150]
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 0             1             I am a student who is learning to code      Yes
# 1             2             I am a student who is learning to code       No
# 2             3  I am not primarily a developer, but I write co...      Yes
# 3             4                     I am a developer by profession       No
# 4             5                     I am a developer by profession      Yes
# ..          ...                                                ...      ...
# 145         147                     I am a developer by profession       No
# 146         148                     I am a developer by profession      Yes
# 147         149                     I am a developer by profession      Yes
# 148         150                     I am a developer by profession      Yes
# 149         151                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# # acess without ending point

# %%
df.iloc[50:]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 50             51             I am a student who is learning to code      Yes
# 51             52                     I am a developer by profession      Yes
# 52             53  I am not primarily a developer, but I write co...      Yes
# 53             54                     I am a developer by profession      Yes
# 54             55             I am a student who is learning to code      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# # Retrieve 1000th respondent with his salary and Country he belongs from

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[1000,["ConvertedComp","Country"]]
# Out:
# ConvertedComp          130847.0
# Country          United Kingdom
# Name: 1000, dtype: object

# %% [markdown]
# # Retrieve top 45 rows form first 5 columns and return their data type(do this on top 2 different data sets)

# %%
h=df.iloc[:45,:5]
h
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
h.dtypes
# Out:
# Respondent      int64
# MainBranch     object
# Hobbyist       object
# OpenSourcer    object
# OpenSource     object
# dtype: object

# %%
r=pd.read_csv("Fifa_world_cup_matches.csv")
r
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %%
s=r.iloc[:45,:5]
s
# Out:
#              team1           team2 possession team1 possession team2  \
# 0            QATAR         ECUADOR              42%              50%
# 1          ENGLAND            IRAN              72%              19%
# 2          SENEGAL     NETHERLANDS              44%              45%
# 3    UNITED STATES           WALES              51%              39%
# 4        ARGENTINA    SAUDI ARABIA              64%              24%
# 5          DENMARK         TUNISIA              55%              33%
# 6           MEXICO          POLAND              54%              31%
# 7           FRANCE       AUSTRALIA              56%              35%
# 8          MOROCCO         CROATIA              32%              57%
# 9          GERMANY           JAPAN              65%              22%
# 10           SPAIN      COSTA RICA              74%              17%
# 11         BELGIUM          CANADA              46%              43%
# 12     SWITZERLAND        CAMEROON              43%              46%
# ...

# %%
s.dtypes
# Out:
# team1                    object
# team2                    object
# possession team1         object
# possession team2         object
# possession in contest    object
# dtype: object

# %% [markdown]
# # - Retrieve Multiple columns with multiple rows from two dataframes

# %%
df.iloc[[1,4,5],[4,5,3]]
# Out:
#                                           OpenSource  \
# 1  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
#
#                            Employment                 OpenSourcer
# 1  Not employed, but looking for work     Less than once per year
# 4                  Employed full-time  Once a month or more often
# 5                  Employed full-time                       Never

# %%
r.iloc[[1,3,4],[2,3,4]]
# Out:
#   possession team1 possession team2 possession in contest
# 1              72%              19%                    9%
# 3              51%              39%                   10%
# 4              64%              24%                   12%

# %% [markdown]
# # Retrieve last 5 rows and last 5 columns and return their column names only

# %%
v=df.iloc[-5:,-5:]
v
# Out:
#                      Sexuality  \
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength SurveyEase
# 88878  Appropriate in length       Easy
# 88879                    NaN        NaN
# 88880                    NaN        NaN
# 88881                    NaN        NaN
# 88882  Appropriate in length       Easy

# %%
v.columns
# Out:
# Index(['Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'], dtype='object')

# %% [markdown]
# # get the index postition any column

# %%
v.columns.get_loc("Sexuality")
# Out:
# 0

# %% [markdown]
# # Create a dictionary which contains keys> Name, Marks,Result

# %%
dict1={"Name":["adnan","messi","ronaldo"],"Marks":[98,74,97],"result":["pass","pass","pass"]}
dict1
# Out:
# {'Name': ['adnan', 'messi', 'ronaldo'],
#  'Marks': [98, 74, 97],
#  'result': ['pass', 'pass', 'pass']}

# %% [markdown]
# # convert dictionary into dataframe

# %%
d=pd.DataFrame(dict1)
d
# Out:
#       Name  Marks result
# 0    adnan     98   pass
# 1    messi     74   pass
# 2  ronaldo     97   pass

# %% [markdown]
# # Access values using square barackets

# %%
d["Name"]
# Out:
# 0      adnan
# 1      messi
# 2    ronaldo
# Name: Name, dtype: object

# %% [markdown]
# # access values using iloc

# %%
d.iloc[2]
# Out:
# Name      ronaldo
# Marks          97
# result       pass
# Name: 2, dtype: object

# %% [markdown]
# # access values using loc

# %%
d.loc[1,"Marks"]
# Out:
# 74

# %% [markdown]
# # Create a data frame which inlcudes a columns with serial number and id columns

# %%
dict1={"Name":["adnan","messi","ronaldo"],"Marks":[98,74,97],"result":["pass","pass","pass"],"serialno":[1,2,3],"id":["a","b","c"]}
dict1
# Out:
# {'Name': ['adnan', 'messi', 'ronaldo'],
#  'Marks': [98, 74, 97],
#  'result': ['pass', 'pass', 'pass'],
#  'serialno': [1, 2, 3],
#  'id': ['a', 'b', 'c']}

# %%
i=pd.DataFrame(dict1)
i
# Out:
#       Name  Marks result  serialno id
# 0    adnan     98   pass         1  a
# 1    messi     74   pass         2  b
# 2  ronaldo     97   pass         3  c

# %% [markdown]
# # make serial column as an index

# %%
i.set_index("serialno",inplace=True)

# %%
i
# Out:
#              Name  Marks result id
# serialno
# 1           adnan     98   pass  a
# 2           messi     74   pass  b
# 3         ronaldo     97   pass  c

# %% [markdown]
# # acess values

# %%
i.loc[1]
# Out:
# Name      adnan
# Marks        98
# result     pass
# id            a
# Name: 1, dtype: object

# %% [markdown]
# # make id column into index

# %%
i.set_index("id",inplace=True)

# %%
i
# Out:
#        Name  Marks result
# id
# a     adnan     98   pass
# b     messi     74   pass
# c   ronaldo     97   pass

# %% [markdown]
# # access value

# %%
i.loc["b"]
# Out:
# Name      messi
# Marks        74
# result     pass
# Name: b, dtype: object

# %% [markdown]
# # On survery Data

# %% [markdown]
# ## How old all the fist 30 respondents

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[:30,"Age"]
# Out:
# 0     14.0
# 1     19.0
# 2     28.0
# 3     22.0
# 4     30.0
# 5     28.0
# 6     42.0
# 7     24.0
# 8     23.0
# 9      NaN
# 10    22.0
# 11    21.0
# 12    28.0
# 13    31.0
# 14    20.0
# 15    26.0
# 16    29.0
# 17     NaN
# 18    31.0
# 19    38.0
# 20     NaN
# 21    47.0
# 22    22.0
# 23    23.0
# 24    22.0
# 25    34.0
# 26    22.0
# 27     NaN
# 28    32.0
# 29    28.0
# 30     NaN
# Name: Age, dtype: float64

# %% [markdown]
# ## Preferred gender of 50 to 100 respondents

# %%
df.loc[50:100,"Gender"]
# Out:
# 50                                                 Woman
# 51                                                   Man
# 52                                                   Man
# 53                                                   Man
# 54                                                   Man
# 55                                                   Man
# 56                                                   Man
# 57                                                   Man
# 58                                                   Man
# 59                                                   Man
# 60                                                   Man
# 61                                                   Man
# 62                                                   Man
# 63                                                   Man
# 64                                                   Man
# 65                                                   NaN
# ...

# %% [markdown]
# ## Most number of respondents are from which country

# %%
df["Country"].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# ## EdLevel and YearsCodPro of 1000 to 1050

# %%
df.loc[1000:1050,["EdLevel","YearsCodePro"]]
# Out:
#                                                 EdLevel      YearsCodePro
# 1000           Bachelor’s degree (BA, BS, B.Eng., etc.)                10
# 1001        Master’s degree (MA, MS, M.Eng., MBA, etc.)                 2
# 1002           Bachelor’s degree (BA, BS, B.Eng., etc.)                 3
# 1003  Some college/university study without earning ...                 5
# 1004  Some college/university study without earning ...                20
# 1005           Bachelor’s degree (BA, BS, B.Eng., etc.)                 4
# 1006        Master’s degree (MA, MS, M.Eng., MBA, etc.)                 6
# 1007        Master’s degree (MA, MS, M.Eng., MBA, etc.)                 2
# 1008  Some college/university study without earning ...                 2
# 1009           Bachelor’s degree (BA, BS, B.Eng., etc.)  Less than 1 year
# 1010        Master’s degree (MA, MS, M.Eng., MBA, etc.)                 7
# 1011        Master’s degree (MA, MS, M.Eng., MBA, etc.)                12
# ...

# %% [markdown]
# ## Response of first 20 respondents to "Student" to "YearsCodePro"

# %%
df.loc[:20,"Student":"YearsCodePro"]
# Out:
#            Student                                            EdLevel  \
# 0               No                          Primary/elementary school
# 1   Yes, full-time  Secondary school (e.g. American high school, G...
# 2               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7              NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8               No  Some college/university study without earning ...
# 9               No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 10  Yes, full-time                          Primary/elementary school
# 11  Yes, full-time  Some college/university study without earning ...
# ...

# %% [markdown]
# ## Return the columns names of all the object type columns

# %%
df.select_dtypes("object")
# Out:
#                                               MainBranch Hobbyist  \
# 0                 I am a student who is learning to code      Yes
# 1                 I am a student who is learning to code       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# ...                                                  ...      ...
# 88878                                                NaN      Yes
# 88879                                                NaN       No
# 88880                                                NaN       No
# 88881                                                NaN       No
# 88882                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %% [markdown]
# ## Return Feature with most number of Nan values

# %%
df.isnull().sum().sum()
# Out:
# 1028850

# %% [markdown]
# # Devs who gets more than 1800000 find their country, age and thier languageworkedwith?

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df[df["ConvertedComp"]>1800000].loc[:,["Country","Age","LanguageWorkedWith"]]
# Out:
#              Country   Age                                 LanguageWorkedWith
# 57     United States  47.0                                        C#;Java;SQL
# 101    United States  37.0              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 164    United States  30.0  Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 434    United States  38.0  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 450    United States  35.0                                            SQL;VBA
# ...              ...   ...                                                ...
# 88162  United States  36.0  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 88264  United States  27.0         HTML/CSS;Java;JavaScript;Kotlin;Python;SQL
# 88266  United States  28.0              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 88321  United States  26.0                               C++;Python;Scala;SQL
# 88324  United States  48.0  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
#
# [731 rows x 3 columns]

# %% [markdown]
# # If devs only earns less than 10000 find their respective country and their edcational background and workingloc?

# %%
df[df["ConvertedComp"]<10000].loc[:,["Country","EdLevel","WorkLoc"]]
# Out:
#             Country                                            EdLevel  \
# 2          Thailand           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 24     South Africa                                   Associate degree
# 32        Argentina        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 49            India           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 58        Argentina  Some college/university study without earning ...
# ...             ...                                                ...
# 88174        Brazil           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88257         Egypt           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88295        France        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88300         Ghana           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88313       Tunisia        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                               WorkLoc
# 2                                                Home
# ...
